# %%
import os

# %%
path = 's3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/'
import subprocess
def make_name(x,y):
    name = 'jacobian_20190401_0000z'
    _is ='_is'
    _js = '_js'
    ext ='.nc4'
    xs,ys=str(x), str(y)
    while(len(xs)<4):
        xs='0' + xs
    while(len(ys)<4):
        ys='0' + ys
    return name+_is+xs+_js+ys+ext
make_name(0,1)
# Out:
# 'jacobian_20190401_0000z_is0000_js0001.nc4'

# %%
import subprocess
import time
t=time.time()
a=subprocess.Popen(['sleep','10'])
print(time.time()-t)
a.wait()
print(time.time()-t)
# Out:
# 0.0075037479400634766
# 10.010502576828003

# %%
# Rattrapage 0 :
d=60
maxy=4261
maxx=661
id0=1
jd0=3541
command =['aws', 's3', 'cp', ]
i=id0
for j in range(jd0, maxy, d):
    fpath = os.path.join(path,make_name(i,j))
    commandi = command.copy()+[fpath, '.']
    subprocess.call(commandi)
    print(fpath, 'done')
# Out:
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0001_js3541.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0001_js3601.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0001_js3661.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0001_js3721.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0001_js3781.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0001_js3841.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0001_js3901.nc4 done
# ...

# %%
import subprocess

d=60
id0 = 1
maxy=4261
maxx=661

id0=61
i=1
jd0=1
command =['aws', 's3', 'cp', ]

for i in range(id0, maxx, d):
    for j in range(jd0, maxy, d):
        fpath = os.path.join(path,make_name(i,j))
        commandi = command.copy()+[fpath, '.']
        subprocess.call(commandi)
        print(fpath, 'done')
# Out:
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0061_js0001.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0061_js0061.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0061_js0121.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0061_js0181.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0061_js0241.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0061_js0301.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0061_js0361.nc4 done
# ...

# %%
# Rattrapage 1 :
d=60
maxy=4261
maxx=661
id0=241
jd0=1921
command =['aws', 's3', 'cp', ]
i=id0
for j in range(jd0, maxy, d):
    fpath = os.path.join(path,make_name(i,j))
    commandi = command.copy()+[fpath, '.']
    subprocess.call(commandi)
    print(fpath, 'done')
# Out:
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0241_js1921.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0241_js1981.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0241_js2041.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0241_js2101.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0241_js2161.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0241_js2221.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0241_js2281.nc4 done
# ...

# %%
import subprocess

d=60
id0 = 1
maxy=4261
maxx=661
id0=241
jd0=1
command =['aws', 's3', 'cp', ]

for i in range(id0, maxx, d):
    for j in range(jd0, maxy, d):
        fpath = os.path.join(path,make_name(i,j))
        commandi = command.copy()+[fpath, '.']
        subprocess.call(commandi)
        print(fpath, 'done')
# Out:
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0241_js0001.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0241_js0061.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0241_js0121.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0241_js0181.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0241_js0241.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0241_js0301.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0241_js0361.nc4 done
# ...

# %%
# Rattrapage 2 : done
d=60
maxy=4261
maxx=661
id0=421
jd0=2881
command =['aws', 's3', 'cp', ]
i=id0
for j in range(jd0, maxy, d):
    fpath = os.path.join(path,make_name(i,j))
    commandi = command.copy()+[fpath, '.']
    subprocess.call(commandi)
    print(fpath, 'done')
# Out:
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0421_js2881.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0421_js2941.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0421_js3001.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0421_js3061.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0421_js3121.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0421_js3181.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0421_js3241.nc4 done
# ...

# %%
# rattrapge
import subprocess

d=60
id0 = 1
maxy=4261
maxx=661
id0=601
jd0=2701
command =['aws', 's3', 'cp', ]
i=id0
for j in range(jd0, maxy, d):
    fpath = os.path.join(path,make_name(i,j))
    commandi = command.copy()+[fpath, '.']
    subprocess.call(commandi)
    print(fpath, 'done')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-94ebcc01c0ae> in <module>
#      13     fpath = os.path.join(path,make_name(i,j))
#      14     commandi = command.copy()+[fpath, '.']
# ---> 15     subprocess.call(commandi)
#      16     print(fpath, 'done')
#
# /usr/lib/python3.6/subprocess.py in call(timeout, *popenargs, **kwargs)
#     287     with Popen(*popenargs, **kwargs) as p:
#     288         try:
# --> 289             return p.wait(timeout=timeout)
#     290         except:
#     291             p.kill()
#
# /usr/lib/python3.6/subprocess.py in wait(self, timeout, endtime)
#    1475                         if self.returncode is not None:
#    1476                             break  # Another thread waited.
# -> 1477                         (pid, sts) = self._try_wait(0)
# ...

# %%
# Rattrapage 3 : done
d=60
maxy=4261
maxx=661
id0=601
jd0=2701
command =['aws', 's3', 'cp', ]
i=id0
for j in range(jd0, maxy, d):
    fpath = os.path.join(path,make_name(i,j))
    commandi = command.copy()+[fpath, '.']
    subprocess.call(commandi)
    print(fpath, 'done')
# Out:
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0601_js2701.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0601_js2761.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0601_js2821.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0601_js2881.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0601_js2941.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0601_js3001.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0601_js3061.nc4 done
# ...

# %%
import subprocess

d=60
id0 = 1
maxy=4261
maxx=661
id0=601
jd0=1
command =['aws', 's3', 'cp', ]

for i in range(id0, maxx, d):
    for j in range(jd0, maxy, d):
        fpath = os.path.join(path,make_name(i,j))
        commandi = command.copy()+[fpath, '.']
        subprocess.call(commandi)
        print(fpath, 'done')
# Out:
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0601_js0001.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0601_js0061.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0601_js0121.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0601_js0181.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0601_js0241.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0601_js0301.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0601_js0361.nc4 done
# ...

# %%
d=60

maxy=4261
maxx=661
jd0 = 2041
i = 181
command =['aws', 's3', 'cp', ]

for j in range(jd0, maxy, d):
    fpath = os.path.join(path,make_name(i,j))
    commandi = command.copy()+[fpath, '.']
    subprocess.call(commandi)
    print(fpath, 'done')
# Out:
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0181_js2041.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0181_js2101.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0181_js2161.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0181_js2221.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0181_js2281.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0181_js2341.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0181_js2401.nc4 done
# ...

# %%
d=60

maxy = 1861
jd0 = 1
i = 241

command =['aws', 's3', 'cp', ]

for j in range(jd0, maxy, d):
    fpath = os.path.join(path,make_name(i,j))
    commandi = command.copy()+[fpath, '.']
    subprocess.call(commandi)
    print(fpath, 'done')
# Out:
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0241_js0001.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0241_js0061.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0241_js0121.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0241_js0181.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0241_js0241.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0241_js0301.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0241_js0361.nc4 done
# ...

# %%
d=60
maxy = 2701
jd0 = 1
i = 421
command =['aws', 's3', 'cp', ]

for j in range(jd0, maxy, d):
    fpath = os.path.join(path,make_name(i,j))
    commandi = command.copy()+[fpath, '.']
    subprocess.call(commandi)
    print(fpath, 'done')
# Out:
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0421_js0001.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0421_js0061.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0421_js0121.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0421_js0181.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0421_js0241.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0421_js0301.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0421_js0361.nc4 done
# ...

# %%
maxy=4261
maxx=661
jd0 = 361
i = 661

for j in range(jd0, maxy, d):
    fpath = os.path.join(path,make_name(i,j))
    commandi = command.copy()+[fpath, '.']
    subprocess.call(commandi)
    print(fpath, 'done')
# Out:
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0661_js0361.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0661_js0421.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0661_js0481.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0661_js0541.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0661_js0601.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0661_js0661.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0661_js0721.nc4 done
# ...

# %%
import os

L = os.listdir('../JC_npy/')
d=60
jd0 = 1
maxy=4262
maxx=662
id0=1
def make_name(x,y):
    name = 'jacobian_20190401_0000z'
    _is ='_is'
    _js = '_js'
    ext ='.npy'
    xs,ys=str(x), str(y)
    while(len(xs)<4):
        xs='0' + xs
    while(len(ys)<4):
        ys='0' + ys
    return name+_is+xs+_js+ys+ext

flag=True
#make_name(i,j)
for i in range(id0, maxx, d):
    for j in range(jd0, maxy, d):
        n = make_name(i,j)
        if n not in L:
            print('No : ', n)
            flag=False
print('All files are here ?', flag)
# Out:
# No :  jacobian_20190401_0000z_is0661_js4261.npy
# All files are here ? False

# %%
maxy=4262
jd0 = 2101
command =['aws', 's3', 'cp', ]

i = 661
for j in range(jd0, maxy, d):
    fpath = os.path.join(path,make_name(i,j))
    commandi = command.copy()+[fpath, '.']
    subprocess.call(commandi)
    print(fpath, 'done')
# Out:
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0661_js2101.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0661_js2161.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0661_js2221.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0661_js2281.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0661_js2341.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0661_js2401.nc4 done
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0661_js2461.nc4 done
# ...

# %%
#L = [(241,1861),(301,3421),(3241,3361),(421,2701)]
L = [(661,2041)]

for (i,j) in L:
    n = make_name(i,j)
    fpath = os.path.join(path,make_name(i,j))
    commandi = command.copy()+[fpath, '.']
    subprocess.call(commandi)

# %% [markdown]
# 0181 || 1981

# %% [markdown]
# 's3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0001_js0001.nc4'

# %% [markdown]
# s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0001_js0001.nc4

# %%
! aws s3 ls
# Out:
# 2018-11-06 17:12:10 academy.jcsda.org
# 2018-10-17 15:11:09 alces-flight-mjhkndmwmzuyy2vm
# 2018-09-20 11:18:33 cf-templates-537ily2tpze9-us-east-1
# 2018-09-15 16:23:46 cf-templates-537ily2tpze9-us-west-2
# 2019-06-19 12:10:58 cosmic.obs.realtime.jcsda.org
# 2018-11-30 12:51:44 data.jcsda.org
# 2018-12-20 16:27:01 elasticbeanstalk-us-east-1-469205354006
# 2018-07-12 17:20:33 fsoi
# 2019-03-13 10:25:19 fsoi-gmao-ingest
# 2018-11-26 12:20:20 fsoi-image-cache
# 2018-11-13 14:27:08 fsoi-navy-ingest
# 2019-03-26 14:31:29 fv3-jedi
# 2019-04-15 14:50:08 fv3gfs
# 2019-06-25 12:29:33 geos.model.realtime.jcsda.org
# 2019-06-19 12:12:44 gfs.model.realtime.jcsda.org
# 2018-10-22 15:33:03 io-benchmarks
# 2018-12-03 11:49:30 ios.jcsda.org
# 2019-02-21 14:23:36 jcsda-lustre-test
# 2019-04-15 14:35:39 jcsda-scratch
# 2019-07-22 12:00:55 jcsda-soca
# 2018-11-06 16:15:09 jcsda-website
# 2018-11-05 09:12:12 jedi-academy
# 2018-08-03 08:24:14 jedi-pub
# ...

# %%
! aws s3 cp s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0001_js0001.nc4 .
# Out:
# download: s3://machine-learning-linearized-physics/TrainingData/20190401_0000z/Jacobians/jacobian_20190401_0000z_is0001_js0001.nc4 to ./jacobian_20190401_0000z_is0001_js0001.nc4
